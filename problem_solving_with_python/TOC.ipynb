# %% [markdown]
# # Problem Solving With Python#
#
# ## Day 1
#
# ### Live Session
#
# - Installing and getting started
# - Data, Statements Basic vocabulary of the language
# - Problem solving on interpreter
# - Building blocks , Functions
#     - builtins
#     - custom
#     - More close look at return statements
#
# ### Assignments and Problems
# Solve all the problems using only what is taught in live session today. do not use any looping technique, condition statements.
#
# - Write a function to count number of digits from an integer
# ```
# >>> countdigits(2**1000)
# 302
# ```
# - Given a single digit, write a statement to create 3 digit number from it. For example if digit is 3, you should be able to generate 333! Write a function to generate n digit number from given digit.
# ```
# >>> ndigitnum(2,5) # first argument is digit and second is how many digit number to form
# 22222
# ```
# - Write a function to find largest digit from n digit number
# ```
# >>> maxdigit(1234346734332)
# 7
# ```
#
#
# ## Day2
#
# ### Live Session
#
# - Discussion of Day1 assignments
# - More about functions, higher order functions
# - methods - Processing text and numeric data using strings, lists, dictionaries
# - conditions
# - loops
#
# ### Assignment Problems
# - Make words from a statement.
# ```
# >>> words("This is plain english text with some words")
# ['This', 'is', 'plain', 'english', 'text', 'with', 'some', 'words']
# ```
# - Count number of words in given text.
# ```
# >>> wordcount("Hello, how are you?")
# 4
# ```
# - Write a function `min2` to find minimum from 2 numbers. Write function `min3` to find minimum from 3 numbers. Make use of conditions and not builtin min
#
# - Given a multigidit integer rearrange its digits to form a max number
# ```
# >>> rearrangemax(4367)
# 7643
# ```
# - From a list of integers find a number whose some of digits is maximum.
# ```
# >>> maxdigitsum([9211,9111,2322,9000,1999])
# 1999
# ```
# - Consider a record consisting of covid19 active statewise cases in india. How will you find a state with max active cases?
# ```
# covid_statewise = {'Andhra Pradesh': 14,
#  'Andaman and Nicobar Islands': 9,
#  'Bihar': 9,
#  'Chandigarh': 8,
#  'Chhattisgarh': 6,
#  'Delhi': 38,
#  'Goa': 2,
#  'Gujarat': 52,
#  'Haryana': 19,
#  'Himachal Pradesh': 3,
#  'Jammu and Kashmir': 31,
#  'Karnataka': 76,
#  'Kerala': 174,
#  'Ladakh': 13,
#  'Madhya Pradesh': 30,
#  'Maharashtra': 183,
#  'Manipur': 1,
#  'Mizoram': 1,
#  'Odisha': 3,
#  'Puducherry': 1,
#  'Punjab': 38,
#  'Rajasthan': 52,
#  'Tamil Nadu': 36,
#  'Telengana': 56,
#  'Uttarakhand': 5,
#  'Uttar Pradesh': 54,
#  'West Bengal': 17}
#  ```
#
# ## Day3
#
# ### Live Session
#
# - modules
#     - introduction to os, sys module
#     - creating custom modules
#     - python script and python module
#     - Installing new modules
#
# ### Problems and Assignments
#
# ## Day4
#
# ### Live Session
#
# - Working with lists/sequences
#     - indexing techniques,
#     - list slicing
#     - list comprehensions
#
# ## Day5
#
# ### Live Session
#
# - Iteration patterns
# - text formatting, creating reports
